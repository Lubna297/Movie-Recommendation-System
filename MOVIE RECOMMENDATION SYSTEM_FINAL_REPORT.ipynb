# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### INTRODUCTION

# %% [markdown]
# Recommendation system is an information filtering system that seeks to predict the rating or the preference a user might give to an item.In other words, it is an algorithm that suggests relevant items to users. It greatly influences with what we interact with the world. What we consume on social media through Facebook, Twitter, Instagram, the personalization we experience while we search, listen, or watch Google, Spotify, YouTube, what we discover using Airbnb and UberEATS, all of these products are powered by Machine Learning and Recommendation systems.
#
# Recommendation System is ubiquitous because of information overload and is growing in popularity in the world of predictive modeling and Machine Learning. In this machine learning project, we will build a recommendation system to suggest movies to the user based on his/her preferences.
#
# To build a movie recommendation system is to provide recommendations to number of users with numerous movies. Recommendation is done based on similarity between users (Collaborative Filtering) or by considering particular user’s activity (Content Based Filtering) which he wants to engage with.
#
# Solid updated data covering user behavior, product (movie) information, and the reviews that link them both is critical. Selecting efficient features as well implementation of advanced machine learning tools and algorithms are also instrumental.

# %% [markdown]
# ### Goal/Objective

# %% [markdown]
# The goal is to build a recommender system that can be applied across various industries, enabling customers to open doors to diverse discoveries and increasing customer lifetime value for the company.
# As we are working on a movie recommendation system, the client of this project could be Netflix, Hulu, Amazon.

# %% [markdown]
# ### Workflow

# %% [markdown]
# The data science project workflow includes:
# 1. Data collection
# 2. Data Wrangling
# 3. Exploratory Data Analysis(EDA)
# 4. Pre-processing and Modeling
# 5. Conclusion and Future works

# %% [markdown]
# ### Data Collection

# %% [markdown]
# Data Source: https://grouplens.org/datasets/movielens/25m/
#
# The dataset for this project was obtained from MovieLens, an online recommendation service. The dataset has two sub-datasets, first one is the 'ratings' dataset which consists of around 25 million user ratings and the second one is the 'movies' dataset which provides information about the movie name, genre and the year of release.

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# The dataset was clean and had no missing values. The 'ratings'dataset has 25,000,095 rows and 4 columns whereas the 'movies'dataset has 62,423 rows and 3 columns.
#
# In the movies dataset, separated the 'genres'column and merged it with the ratings dataset for better Data Exploration, and
# removed the year from the 'title' column and made the 'year' and 'Decade' as separate columns.

# %% [markdown]
# ### Exploratory Data Analysis(EDA)

# %% [markdown]
# Initial investigations on data were carried out through Data visualization and statistical techniques so as to discover patterns and spot any anomalies. EDA helps understand and gather as many insights from the data.

# %% [markdown]
# #### Observations

# %% [markdown]
# 1. Total number of movies per each Genre:
#
#    ***Drama and Comedy*** have the most production followed by ***Thriller, Romance and Action***.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Total number of movies in each decade
#
#    The plot shows an increasing trend with most of the production being in the **2010** decade.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#   #### Movie titles repeated several times are:

# %% [markdown]
# Hamlet and Miserable, Les

# %% [markdown]
# ***Miserable,Les***![image-2.png](attachment:image-2.png) ***Hamlet***![image-3.png](attachment:image-3.png)

# %% [markdown]
# ***Top 10 movies with the max number of ratings***
# Forrest Gump, Shawshank Redemption and Pulp Fiction respectively.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Boxplot of 'Decade' vs 'Rating'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Boxplot of the 'Decade' vs 'Genres'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Boxplot of the 'Ratings' vs 'Genres'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It was observed that the genres 'Crime', 'Drama', 'War', 'Mystery' are some of the most rated ones.

# %% [markdown]
# #### WORD CLOUD
#
# Word cloud for Titles : The most common word used in movie titles is "Love".

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# 1. Dropped the column 'Timestamp' from the movielens dataset.
#
# 2. Filtered the movies only with more than 100 vote counts for better recommendation results.
#
#    Sklearn library was used to train and test the data.

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Recommender Systems

# %% [markdown]
# #### 1. Simple Recommender System

# %% [markdown]
# This recommender system generalizes the recommendations to the users based on movie popularity, ratings and genre. Hence, the popular and highly acclaimed movies will have a higher probability of being liked by the audience.
#
# This model does not give personalized recommendations based on a particular user.
# Movies were sorted based on the genre and were recommended accordingly.

# %% [markdown]
# #### Top 10 Drama movies recommended are:

# %% [markdown]
# 1 : Shawshank Redemption, The (1994)
#
# 2 : Pulp Fiction (1994)
#
# 3 : Schindler's List (1993)
#
# 4 : Fight Club (1999)
#
# 5 : American Beauty (1999)
#
# 6 : Godfather, The (1972)
#
# 7 : Fargo (1996)
#
# 8 : Dark Knight, The (2008)
#
# 9 : Inception (2010)
#
# 10 : One Flew Over the Cuckoo's Nest (1975)

# %% [markdown]
# #### Top 10 'Action' movies recommended are:

# %% [markdown]
# 1 : Matrix, The (1999)
#
# 2 : Star Wars: Episode IV - A New Hope (1977)
#
# 3 : Braveheart (1995)
#
# 4 : Fight Club (1999)
#
# 5 : Star Wars: Episode V - The Empire Strikes Back (1980)
#
# 6 : Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)
#
# 7 : Lord of the Rings: The Return of the King, The (2003)
#
# 8 : Saving Private Ryan (1998)
#
# 9 : Dark Knight, The (2008)
#
# 10 : Inception (2010)

# %% [markdown]
# #### Top 10 'Romance' movies recommended are:

# %% [markdown]
# 1 : Forrest Gump (1994)
#
# 2 : American Beauty (1999)
#
# 3 : Shrek (2001
#
# 4 : Good Will Hunting (1997
#
# 5 : Princess Bride, The (1987)
#
# 6 : Groundhog Day (1993)
#
# 7 : Beauty and the Beast (1991)
#
# 8 : Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001
#
# 9 : Eternal Sunshine of the Spotless Mind (2004)
#
# 10 : Beautiful Mind, A (2001)

# %% [markdown]
# #### 2. IMDB Weighted Rating Formula

# %% [markdown]
# IMDb stands for Internet Movie Database, which publishes weighted vote averages rather than just raw data averages. In other words, although we accept and consider all votes received by users, not all votes have the same impact (or 'weight') on the final rating.
#
# The top rated movies recommended by the IMDb recommender system are:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. Content-based Filtering

# %% [markdown]
# Content-based filtering uses item features to recommend other items similar to what the user likes, based on their previous actions or explicit feedback. Content-based filtering makes recommendations by using keywords and attributes assigned to objects in a database (e.g., items in an online marketplace) and matching them to a user profile.

# %% [markdown]
# RMSE for this model came around 0.94, which is too high and hence not considered feasible for predicting or recommending for this dataset.

# %% [markdown]
# #### 4. Collaborative Filtering

# %% [markdown]
# **a) Simple collaborative filtering**

# %% [markdown]
# It recommends based on other user's rating history. For instance, using the mean as an aggregate function.
#
# The results of random users and movie Id are displayed below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### b) Matrix Factorization based Algorithm

# %% [markdown]
# **i) SVD (Singular Value Decomposition)**

# %% [markdown]
# SVD is a matrix factorization technique that is used to reduce the number of features of a dataset by reducing the space dimensions from N to K, where K< N. For the recommendation systems, we will focus on the matrix factorization keeping the same dimensionality. It is done on the user-item ratings matrix. For instance, matrix factorization can be regarded as finding two matrices whose product is the original matrix.

# %% [markdown]
# **Surprise library** was used which consists of several powerful algorithms like SVD, NMF(Non-negative Matrix Factorization). KNN(K- Nearest Neighbor) and Co-Clustering, to minimize the RMSE(Root Mean Square Error) and give accurate recommendations.

# %% [markdown]
# **Observations**

# %% [markdown]
# **SVD** ![image.png](attachment:image.png)

# %% [markdown]
# **NMF** ![image.png](attachment:image.png)

# %% [markdown]
# **KNN** ![image.png](attachment:image.png)

# %% [markdown]
# **Co-Clustering** ![image.png](attachment:image.png)

# %% [markdown]
# It was observed that the RMSE for all the algorithms were higher than 0.5, which is not considered feasible. Hence, we tried Hyperparameter tuning as an attempt to reduce the RMSE but that also did not give us much different results. The RMSE after Hyperparameter tuning was found to be around **0.664**. Therefore, we tried SVD++.

# %% [markdown]
# #### ii) SVD ++

# %% [markdown]
# SVD++ algorithm is an extension of SVD that takes into account the implicit ratings. In other words, it as an optimized SVD algorithm to enhance the accuracy of prediction by generating implicit feedback.

# %% [markdown]
# However, SVD++ also did not give us any good results. The RMSE for this algorithm was found to be around **0.65.**

# %% [markdown]
# #### iii) LightFM Model

# %% [markdown]
# LightFM is a Python implementation of a number of popular recommendation algorithms for both implicit and explicit feedback. It is a hybrid matrix factorisation model representing users and items as linear combinations of their content features' latent factors.
#
# It also makes it possible to incorporate both item and user metadata into the traditional matrix factorization algorithms. It represents each user and item as the sum of the latent representations of their features, thus allowing recommendations to generalise to new items (via item features) and to new users (via user features).

# %% [markdown]
# ***Observations:***

# %% [markdown]
# The LightFM model gave us the precision at K score of around **0.053** and an AUC score of **0.91**, which is quite good. To further improve the model, we tried Hyperparameter Tuning.

# %% [markdown]
# After Hyperparameter Tuning, the model performance was enchanced by **3%** and we got an outstanding AUC score of **0.94**. Hence, this model is considered a good recommender system for this dataset.

# %% [markdown]
# #### iv) Alternating Least Square (ALS) Collaborative Filtering

# %% [markdown]
# ALS is also a matrix factorization algorithm, which factorizes a given matrix R into two factors U and V such that R≈UTV. The unknown row dimension is given as a parameter to the algorithm and is called latent factors.
#
# AlS is an iterative optimization process where for every iteration, we move closer to an factorized representation of our original data. We will use this model to fit our data and find the similarities.

# %% [markdown]
# 1. Movies similar to Shawshank Redemption

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Movies similar to Forrest Gump

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the above results, it is observed that the ALS model also gives good scores and hence, accurate recommendations for this dataset.
